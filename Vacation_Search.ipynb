# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
from citipy import citipy

# %%
# Import the google API key.
from config import g_key

# %%
import requests

# %%
import gmaps
import gmaps.datasets

# %%
#Import the WeatherPy_vacation.csv file from Part 1 as a new DataFrame.
vacation_cities_df = pd.read_csv("weather_data/WeatherPy_challenge.csv")
vacation_cities_df.head()
# Out:
#    City_ID            City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     Yellowknife  62.46 -114.35     62.01        29          20
# 1        1     Yellowknife  62.46 -114.35     62.01        29          20
# 2        2         Mataura -46.19  168.86     37.80        78          50
# 3        3         Mataura -46.19  168.86     37.80        78          50
# 4        4  Cabo San Lucas  22.89 -109.91     93.00        45           5
#
#    Wind Speed Country Current description  Rain (last 3 hrs)  \
# 0       10.29      CA          few clouds                0.0
# 1       10.29      CA                 NaN                NaN
# 2        2.51      NZ    scattered clouds                0.0
# 3        2.51      NZ                 NaN                NaN
# 4       11.41      MX           clear sky                0.0
#
#    Snow (last 3 hrs)                 Date
# 0                0.0  2020-05-30 21:19:58
# 1                NaN  2020-05-30 21:19:58
# 2                0.0  2020-05-30 21:19:51
# 3                NaN  2020-05-30 21:19:51
# 4                0.0  2020-05-30 21:15:40

# %%
#Filter the DataFrame for minimum and maximum temperature preferences, and if the rain or snow accumulation is 0 inches or not

# Ask the customer the desired weather condition at the vacation destination.
destination_min_temp  = float(input("What is the minimum temperature at your vacation destination? "))
destination_max_temp  = float(input("What is the maximum temperature at your vacation destination? "))
destination_want_rain = input("Do you want it to be raining at your vacation destination? (yes/no) ")
destination_want_snow = input("Do you want it to be snowing at your vacation destination? (yes/no) ")

if destination_want_rain is None:
    destination_want_rain = "no"
    
if destination_want_snow is None:
    destination_want_snow = "no"

print()
print(f"Searching for destinations where the current temperature is between {destination_min_temp} and {destination_max_temp}")   
print(f"Show destinations where it is currently raining [{destination_want_rain}] or currently snowing [{destination_want_snow}]")
# Out:
# What is the minimum temperature at your vacation destination? 70
# What is the maximum temperature at your vacation destination? 90
# Do you want it to be raining at your vacation destination? (yes/no) no
# Do you want it to be snowing at your vacation destination? (yes/no) no
#
# Searching for destinations where the current temperature is between 70.0 and 90.0
# Show destinations where it is currently raining [no] or currently snowing [no]

# %%
#Add the cities to a marker layer map with a pop-up marker for each  city

# Filter the dataset to find the cities that fit the criteria.
if ( destination_want_rain.lower() != "yes" and destination_want_snow.lower() != "yes"):
    
    print("Looking for destinations where it IS NOT raining and IS NOT snowing")
    
    preferred_cities_df = vacation_cities_df.loc[
                                    (vacation_cities_df["Max Temp"] <= destination_max_temp) & 
                                    (vacation_cities_df["Max Temp"] >= destination_min_temp) & 
                                    (vacation_cities_df["Rain (last 3 hrs)"] == 0) & 
                                    (vacation_cities_df["Snow (last 3 hrs)"] == 0), :]

elif destination_want_rain.lower() == "yes":
    
    print("Looking for destinations where it IS raining")
    
    preferred_cities_df = vacation_cities_df.loc[
                                    (vacation_cities_df["Max Temp"] <= destination_max_temp) & 
                                    (vacation_cities_df["Max Temp"] >= destination_min_temp) & 
                                    (vacation_cities_df["Rain (last 3 hrs)"] > 0) &
                                    (vacation_cities_df["Snow (last 3 hrs)"] == 0), :]
    
elif len(destination_want_snow) > 0 and destination_want_snow.lower() == "yes":
    
    print("Looking for destinations where it IS snowing")
    
    preferred_cities_df = vacation_cities_df.loc[
                                    (city_data_df["Max Temp"] <= destination_max_temp) & 
                                    (city_data_df["Max Temp"] >= destination_min_temp) & 
                                    (city_data_df["Rain (last 3 hrs)"] == 0) &
                                    (city_data_df["Snow (last 3 hrs)"] > 0), :]
# Out:
# Looking for destinations where it IS NOT raining and IS NOT snowing

# %%
preferred_cities_df.head(10)
# Out:
#     City_ID             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 6         6  Emilio Carranza  19.97  -96.61     80.76        65          94
# 16       16        Ugoofaaru   5.67   73.00     80.60        80         100
# 20       20             Auki  -8.77  160.70     81.05        79           9
# 22       22          Hualmay -11.10  -77.61     70.38        74          89
# 30       30           Atuona  -9.80 -139.03     80.94        78           1
# 32       32           Akhmim  26.56   31.75     82.40        22           0
# 38       38     Puerto Ayora  -0.74  -90.35     84.20        58          40
# 40       40        Mogadishu   2.04   45.34     80.28        82          97
# 52       52        Kilindoni  -7.91   39.67     80.76        78           0
# 54       54           Albany  42.60  -73.97     79.00        48           0
#
#     Wind Speed Country Current description  Rain (last 3 hrs)  \
# 6        16.33      MX     overcast clouds                0.0
# 16       12.06      MV     overcast clouds                0.0
# 20        3.44      SB           clear sky                0.0
# 22        9.37      PE     overcast clouds                0.0
# 30       18.48      PF          light rain                0.0
# 32       16.11      EG           clear sky                0.0
# 38       23.04      EC    scattered clouds                0.0
# 40       14.38      SO     overcast clouds                0.0
# 52       15.30      TZ          light rain                0.0
# 54        1.01      US           clear sky                0.0
#
#     Snow (last 3 hrs)                 Date
# 6                 0.0  2020-05-30 21:27:49
# 16                0.0  2020-05-30 21:20:23
# 20                0.0  2020-05-30 21:19:50
# 22                0.0  2020-05-30 21:19:51
# 30                0.0  2020-05-30 21:19:38
# 32                0.0  2020-05-30 21:27:50
# 38                0.0  2020-05-30 21:19:58
# 40                0.0  2020-05-30 21:27:50
# 52                0.0  2020-05-30 21:27:51
# 54                0.0  2020-05-30 21:19:41

# %%
# Create DataFrame to store hotel names along with city, country, current weather description, and coordinates.
preferred_cities_w_hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current description", "Lat", "Lng"]].copy()

# Add hotel name field to the data frame.
preferred_cities_w_hotel_df["Hotel Name"] = ""

preferred_cities_w_hotel_df.head(10)
# Out:
#                City Country  Max Temp Current description    Lat     Lng  \
# 6   Emilio Carranza      MX     80.76     overcast clouds  19.97  -96.61
# 16        Ugoofaaru      MV     80.60     overcast clouds   5.67   73.00
# 20             Auki      SB     81.05           clear sky  -8.77  160.70
# 22          Hualmay      PE     70.38     overcast clouds -11.10  -77.61
# 30           Atuona      PF     80.94          light rain  -9.80 -139.03
# 32           Akhmim      EG     82.40           clear sky  26.56   31.75
# 38     Puerto Ayora      EC     84.20    scattered clouds  -0.74  -90.35
# 40        Mogadishu      SO     80.28     overcast clouds   2.04   45.34
# 52        Kilindoni      TZ     80.76          light rain  -7.91   39.67
# 54           Albany      US     79.00           clear sky  42.60  -73.97
#
#    Hotel Name
# 6
# 16
# 20
# 22
# 30
# 32
# 38
# 40
# 52
# 54

# %%
# Google nearby search URL endpoint.
url_google_nearbysearch = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

hotels_found_count = 0
city_name_padding = preferred_cities_w_hotel_df['City'].str.len().max()

# Create parameter object for nearby search.
params = {
    "radius": 5000, # in meeters
    "types": "lodging", # Only looking for hotels
    "key": g_key,
    "location": "Lat:Lng"
         }

# Iterate through the preferred cities data frame
# and add hotel information.
for index, row in preferred_cities_w_hotel_df.iterrows():
    
    # Get current data frame city's latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Update the location key in the request parameters.
    params["location"] = f"{lat},{lng}"
   
    # Request nearby search for hotels.
    hotels_nearby_results = requests.get(url_google_nearbysearch, params=params).json()
 
    # Get name of the first hotel in the the nearby search result set.
    try:        
        hotel_name = hotels_nearby_results["results"][0]["name"]
        print("City: " + row['City'].ljust(city_name_padding) + "  Hotel: " + hotel_name)
        preferred_cities_w_hotel_df.loc[index, "Hotel Name"] = hotel_name
        hotels_found_count +=1
    except:
        print("City: " + row['City'].ljust(city_name_padding) + "  Hotel: *** NO HOTEL FOUND *** ... Dropping row.")
        preferred_cities_w_hotel_df.drop([index])
# Out:
# City: Emilio Carranza           Hotel: hotel delicias
# City: Ugoofaaru                 Hotel: Ungoofaaru Inn
# City: Auki                      Hotel: Auki Motel
# City: Hualmay                   Hotel: Hotel Restaurant Turístico Casablanca
# City: Atuona                    Hotel: Villa Enata
# City: Akhmim                    Hotel: برج الماسة السكني
# City: Puerto Ayora              Hotel: Finch Bay Galapagos Hotel
# City: Mogadishu                 Hotel: Hotel Juba
# City: Kilindoni                 Hotel: Bustani B&B
# City: Albany                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Ontario                   Hotel: DoubleTree by Hilton Hotel Ontario Airport
# City: Staunton                  Hotel: Stonewall Jackson Hotel
# City: Butaritari                Hotel: Isles Sunset Lodge
# City: Shahreza                  Hotel: خوابگاه
# City: Rikitea                   Hotel: Pension Maro'i
# City: Kapaa                     Hotel: Sheraton Kauai Resort at Coconut Beach
# City: Hilo                      Hotel: Hilo Hawaiian Hotel
# City: Sao Domingos Do Maranhao  Hotel: Pousada Babaçu
# City: Hashtgerd                 Hotel: Parse System
# City: Avarua                    Hotel: Paradise Inn
# City: Rutul                     Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Inhambane                 Hotel: MHL Turismo SA
# City: Bethel                    Hotel: Courtyard by Marriott Danbury
# City: Bonthe                    Hotel: Bonthe Holiday Village
# City: Vaini                     Hotel: Keleti Beach Resort
# City: Arraial Do Cabo           Hotel: Pousada Porto Praia
# City: Srandakan                 Hotel: Puri Brata
# City: Puerto Escondido          Hotel: Aldea del Bazar Hotel and Spa
# City: Hithadhoo                 Hotel: Scoop Guest House
# City: Kavieng                   Hotel: Nusa Island Retreat
# City: Wajir                     Hotel: Al- Amin lodge
# City: Georgetown                Hotel: Cititel Penang
# City: Karratha                  Hotel: ibis Styles Karratha
# City: La Libertad               Hotel: Playa Canela Hotel Boutique
# City: Sao Filipe                Hotel: Tortuga B&B
# City: Kota Belud                Hotel: Tang Dynasty Lodge Kota Belud
# City: Nioki                     Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Mecca                     Hotel: Hotel Fairmont Makkah Clock Royal Tower
# City: Daru                      Hotel: New century hotel
# City: Kingston                  Hotel: The Jamaica Pegasus Hotel
# City: Salalah                   Hotel: HAMDAN PLAZA HOTEL
# City: Okmulgee                  Hotel: Holiday Inn Express & Suites Okmulgee
# City: Sangueya                  Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: San Cristobal             Hotel: Pirineos
# City: Dingle                    Hotel: Camp Pasica
# City: Cockburn Town             Hotel: Osprey Beach Hotel
# City: Bathsheba                 Hotel: Atlantis Hotel
# City: Port Blair                Hotel: Hotel Sentinel
# City: Sitio Novo Do Tocantins   Hotel: Imperial Hotel
# City: Clifton                   Hotel: La Quinta Inn & Suites by Wyndham Clifton/Rutherford
# City: Jalu                      Hotel: Jalu Hotel
# City: Porto Novo                Hotel: Tour Eiffel Hotel Benin
# City: Davila                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Ocos                      Hotel: La Bajadita
# City: Korla                     Hotel: Gulisitan Hotel
# City: Touros                    Hotel: INN NEW HORIZON
# City: Coahuayana                Hotel: Hotel Los Arcos
# City: Nago                      Hotel: Hotel Yugaf Inn Okinawa
# City: Pitimbu                   Hotel: Reserva do Abiaí
# City: Hambantota                Hotel: Bungalow 63
# City: Aitape                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Conde                     Hotel: Pousada Beija Flor
# City: Biltine                   Hotel: Hôtel Trois Étoiles de Biltine
# City: Sassandra                 Hotel: la terrasse
# City: Tumpat                    Hotel: OYO 44005 Senangin Resort & Cafe
# City: Madang                    Hotel: Comfort Inn Hotel
# City: Lorengau                  Hotel: Lorengau Harbourside Hotel
# City: Sao Felix Do Xingu        Hotel: Apart Hotel Rio Xingu
# City: Faanui                    Hotel: Bora-Bora Pearl Beach Resort & Spa
# City: Kahului                   Hotel: Maui Seaside Hotel
# City: Conakry                   Hotel: Riviera Royal Hotel
# City: Gamba                     Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Hobyo                     Hotel: Osmani Hotel
# City: Cao Bang                  Hotel: khách sạn 88
# City: Ewa Beach                 Hotel: Parkside By Gentry
# City: Victoria                  Hotel: Mini Hotel Central
# City: Amapa                     Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Isangel                   Hotel: Volcano Sea View Tree House
# City: Elk City                  Hotel: Hampton Inn & Suites Elk City
# City: Tarakan                   Hotel: Hotel D' CaLia Tarakan
# City: Bambous Virieux           Hotel: Casa Tia Villa
# City: Asyut                     Hotel: Florence Hotel Assiut
# City: Bryan                     Hotel: Best Western Premier Bryan College Station
# City: Ayna                      Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Payakumbuh                Hotel: OYO 3114 Homestay Dalimo
# City: Zhezkazgan                Hotel: Kvartiry Posutochno.
# City: Cayenne                   Hotel: Hôtel Le Dronmi
# City: Bengkulu                  Hotel: Grage Hotel Bengkulu
# City: Nabire                    Hotel: Hotel Nusantara Nabire
# City: Kampong Thum              Hotel: Sambor Village Hotel
# City: Komsomolskiy              Hotel: Hotel "Ikathouse"
# City: Roebourne                 Hotel: Harding River Caravan Park
# City: Orchard Homes             Hotel: Broadway Inn Missoula
# City: Bakel                     Hotel: Hôtel islam
# City: Umiray                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Kudahuvadhoo              Hotel: Kudahuvadhoo Retreat
# City: Yanam                     Hotel: The Regency Hotel
# City: Male                      Hotel: Hotel Octave Maldives
# City: Virginia Beach            Hotel: Hilton Virginia Beach Oceanfront
# City: La Asuncion               Hotel: Colinas de Matasiete
# City: Qui Nhon                  Hotel: Khách sạn Hải Âu Quy Nhơn - Seagull Hotel
# City: Itaueira                  Hotel: Hotel Pousada Luz
# City: Savannah Bight            Hotel: Villa on Dunbar Rock
# City: Lazaro Cardenas           Hotel: Hotel Quinta Antigua
# City: Merauke                   Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Tautira                   Hotel: Pension Oaoa
# City: Watrous                   Hotel: Manitou Hotel
# City: Mattru                    Hotel: Boima Gbondo's Compound
# City: Tutoia                    Hotel: Pousada Guará's
# City: Mitsamiouli               Hotel: Foyer ADM
# City: Bonito                    Hotel: Marruá Hotel
# City: Ygatimi                   Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Labuhan                   Hotel: bador sepret
# City: Sur                       Hotel: Sur Plaza Hotel
# City: Namatanai                 Hotel: Namatanai Hotel
# City: Demba                     Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Alofi                     Hotel: Taloa Heights
# City: Cotonou                   Hotel: Novotel Cotonou Orisha
# City: Hoi An                    Hotel: Belle Maison Hadana Hoi An Resort & Spa managed by H&K Hospitality
# City: San Carlos                Hotel: Hotel Paternopoli
# City: Broome                    Hotel: Chenango Valley State Park
# City: Cedar City                Hotel: Hampton Inn Cedar City
# City: Bombay                    Hotel: Four Seasons Hotel Mumbai
# City: San Patricio              Hotel: Hotel Cabo Blanco
# City: San Matias                Hotel: HOTEL "SAN JOSE"
# City: Marica                    Hotel: Marica Hills
# City: Sagaing                   Hotel: Hotel Golden World
# City: Moratuwa                  Hotel: Sa Mansion By Yoho
# City: Tura                      Hotel: Hotel RIKMAN Continental
# City: Xushan                    Hotel: Hangzhou Bay Hotel
# City: Tabuk                     Hotel: RVF cebu lechon
# City: Kollam                    Hotel: The Raviz Ashtamudi
# City: Axim                      Hotel: AXIM BEACH RESORT AND SPA
# City: Santa Isabel              Hotel: Chácara Sombra do Altíssimo
# City: Wenling                   Hotel: Hanting Express Wenling Wanchang North Road
# City: Manali                    Hotel: Sarathy Lodge
# City: Marrakesh                 Hotel: Les Jardins de La Koutoubia
# City: Tshikapa                  Hotel: Hôtel Tshia-Muntu de Tshikapa
# City: Matara                    Hotel: Amaloh Boutique Resort
# City: Namibe                    Hotel: Chik-Chik Namibe
# City: Shu                       Hotel: Shyngyzkhan
# City: San Policarpo             Hotel: Zal-Ann Beach Resort
# City: Tomatlan                  Hotel: Norma franco
# City: Atyrau                    Hotel: River Palace Hotel
# City: Biak                      Hotel: Kost Ariz
# City: Guerrero Negro            Hotel: Casa Laguna, Bed & Breakfast
# City: Dicabisagan               Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Takoradi                  Hotel: Raybow International Hotel
# City: Grand Gaube               Hotel: Veranda Paul et Virginie Hotel & Spa
# City: Balikpapan                Hotel: Swiss-Belhotel Balikpapan
# City: Marawi                    Hotel: Derogongan Residence
# City: Khambhat                  Hotel: Anand
# City: Newark                    Hotel: Best Western Plus Robert Treat Hotel
# City: Kalianget                 Hotel: Pesanggrahan Garam
# City: Singapore                 Hotel: Swissôtel The Stamford
# City: Daud Khel                 Hotel: MLCFL CFPP Hostel 6
# City: Catumbela                 Hotel: Hotel Do Kamgamba
# City: Caravelas                 Hotel: Pousada dos Navegantes
# City: Port Keats                Hotel: TDC Village (Hundred Man Camp)
# City: Frontera                  Hotel: Fiesta Inn Monclova
# City: Ukwa                      Hotel: Chouksey Hotel & Rajat Transport
# City: Katobu                    Hotel: La Ode Gombe
# City: San Ramon                 Hotel: San Ramon Marriott
# City: Ilebo                     Hotel: Hôtel des palmes
# City: Mazatlan                  Hotel: Gaviana Resort
# City: Itaituba                  Hotel: Hotel Campos
# City: Vao                       Hotel: Hotel Kou-Bugny
# City: Banda Aceh                Hotel: OYO 884 Rumoh PMI Hotel
# City: Omboue                    Hotel: Hotel Olako
# City: Mainit                    Hotel: P&G Apartment
# City: Bocaue                    Hotel: 3Ds HOMEMADE SPECIALTIES
# City: Alugan                    Hotel: BEMBEM RAIN FEED RESORT
# City: Lafia                     Hotel: Low Cost Housing Estate
# City: Kutum                     Hotel: Dibbo areaمنطقة دبو
# City: Abong Mbang               Hotel: Hotel Delice Du Haut Nyong
# City: Banjar                    Hotel: The Hamsa Resort
# City: Tabou                     Hotel: hotêl doufoulougou
# City: Ixtapa                    Hotel: Container Inn Puerto Vallarta
# City: Kedougou                  Hotel: Relais de Kédougou
# City: Aquiraz                   Hotel: Pousada Rua Camurupim
# City: Nanlong                   Hotel: Demei Hotel
# City: San Quintin               Hotel: Old Mill Hotel
# City: Fare                      Hotel: Maitai Lapita Village Huahine
# City: Catia La Mar              Hotel: HOTEL PLAYA GRANDE CARIBE
# City: Hamilton                  Hotel: Six Acres Bed & Breakfast
# City: Shubarkuduk               Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Marsh Harbour             Hotel: Abaco Beach Resort
# City: Pangkalanbuun             Hotel: Grand Kecubung Hotel
# City: Sakhipur                  Hotel: সুইট হোম, মাস্টার বাড়ী
# City: Kaka                      Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Ajdabiya                  Hotel: فندق التوجان
# City: Alta Floresta             Hotel: Floresta Amazonica Hotel
# City: Bolobo                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Cody                      Hotel: Buffalo Bill (Cabins) Village
# City: Vilhena                   Hotel: Hotel Mirage
# City: Benjamin Constant         Hotel: CASA AVALIADA
# City: Fairfield                 Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Tiarei                    Hotel: Le Rocher de Tahiti
# City: Aswan                     Hotel: Nuba Nile
# City: Buta                      Hotel: HOTEL BISO NA BISO
# City: Sinait                    Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Half Moon Bay             Hotel: The Ritz-Carlton, Half Moon Bay
# City: Tambura                   Hotel: Guest hous Tambura
# City: Jacareacanga              Hotel: Casa do Ian😎
# City: Fairbanks                 Hotel: Westmark Fairbanks Hotel & Conference Center
# City: Tahta                     Hotel: Møhãmęd Tãręk 🏠
# City: Sabha                     Hotel: محطة ام الارانب -سبها مواصلات
# City: Inyonga                   Hotel: Eden Rock Lodge
# City: Japura                    Hotel: KOST dan HOMESTAY RUMAH KITA JOSH
# City: Padang                    Hotel: Mercure Padang
# City: Waingapu                  Hotel: Pondok Wisata Elim
# City: Cartagena Del Chaira      Hotel: HOTEL LA ROCA
# City: Sarangani                 Hotel: Ballistic Islet
# City: Boyuibe                   Hotel: Residencial Eluzai
# City: Buala                     Hotel: Maringe Lagoon Lodge
# City: Cap Malheureux            Hotel: Pereybere Hotel & Spa
# City: Itacoatiara               Hotel: BBB Rooms Centro Itacoatiara AM
# City: Smoky Lake                Hotel: Country Garden Hotel
# City: Shihezi                   Hotel: Home Inn Shihezi Dongwu Road Century Square
# City: Chickasha                 Hotel: Holiday Inn Express & Suites Chickasha
# City: Adre                      Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Marigot                   Hotel: Royal Palm Beach Resort
# City: Angoram                   Hotel: *** NO HOTEL FOUND *** ... Dropping row.
# City: Sinnamary                 Hotel: ALETHEIA Appartement Sinnamary
# City: Mae Sai                   Hotel: Piyaporn Hill Paradise Hotel
# City: Veraval                   Hotel: Lords Inn Somnath
# City: Maceio                    Hotel: Mercure Maceio Pajucara Hotel
# City: Tibu                      Hotel: Residencias Copetran
# City: Kimbe                     Hotel: Kimbe Bay Hotel
# City: Canyon                    Hotel: Holiday Inn Express & Suites Canyon
# City: College                   Hotel: Pike's Waterfront Lodge
# City: Chabahar                  Hotel: هتل گدروشیا
# City: Sola                      Hotel: Leumerus Bungalows
# City: Odweyne                   Hotel: Eng Hiirey House
# City: Port Hedland              Hotel: The Esplanade Hotel
# City: Turbat                    Hotel: Mubashar Quarters
# City: San Jose                  Hotel: The Westin San Jose
# City: Ibra                      Hotel: مزرعة راحة النفوس المنزفة
# City: Bani                      Hotel: Hospedaje Henriquez
# City: Sibolga                   Hotel: Hotel Syariah CN Darussalam
# City: Pemangkat                 Hotel: Kost H.Syamsuddin

# %%
# Save the perferred cities with nearby hotels information to csv file without the index column
preferred_cities_w_hotel_df.to_csv("weather_data/WeatherPy_vacation.csv", index=False)

# %%
# Popup markers template for destination cities with hotel and weather information
destination_city_info_box_template = """
<dl>
    <dt>Hotel Name</dt>
        <dd>{Hotel Name}</dd>
    <dt>City</dt>
        <dd>{City}</dd>
    <dt>Country</dt>
        <dd>{Country}</dd>
    <dt>Current Weather</dt>
        <dd>{Current description} and {Max Temp} °F</dd>
</dl>
"""
# Create google map pop marker info boxes for destination cities.
destination_city_info_boxes = [destination_city_info_box_template.format(**row) for index, row in preferred_cities_w_hotel_df.iterrows()]

# Get destination cities locations
destination_city_locations = preferred_cities_w_hotel_df[["Lat", "Lng"]]

# # Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# Add a pop-up marker for each city.
marker_layer = gmaps.marker_layer(destination_city_locations, info_box_content=destination_city_info_boxes)

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
